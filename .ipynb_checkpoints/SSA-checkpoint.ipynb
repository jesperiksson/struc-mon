# %%
import numpy as np
import matplotlib.pyplot as plt
from pyts.decomposition import SingularSpectrumAnalysis

# %%
from Model import *
from SQLAConnection import SQLAConnection 
from QueryGenerator import QueryGenerator
from Data import Data
import Settings

# %%
settings = Settings.Settings()
model = TimeSeriesPredictionNeuralNet(settings)
connection = SQLAConnection()
query_generator = QueryGenerator(
    settings.sensors,
    settings.start_date,
    settings.end_date
    )
data = Data(query_generator,connection)

# %%
data.load_dfs(date='2020-11-01')
df = data.dfs[0]
print(len(df))
# Out:
# 46275

# %%
n_timestamps = 50
n_samples = int(len(df)/n_timestamps)
#n_samples, n_timestamps = 15425, 3
X = data.dfs[0]['acc1_ch_y'].iloc[:n_samples*n_timestamps].to_numpy().reshape(n_samples,n_timestamps)
#print(X)
# Out:
# [[ 0.05892419  0.79978978 -0.8379131  ... -0.23352275 -1.44230345
#    1.24820842]
#  [-0.6819414   0.64381807  1.09223672 ... -0.38949446 -0.99388481
#   -0.23352275]
#  [ 0.05892419  0.05892419  0.35137113 ...  0.05892419 -0.38949446
#   -0.8379131 ]
#  ...
#  [-0.38949446  0.21489589  1.54065537 ...  2.28152096 -0.23352275
#    1.54065537]
#  [ 0.95576148 -0.09704751  1.85259877 ...  0.21489589  2.8859113
#   -1.44230345]
#  [-0.23352275 -0.38949446  0.64381807 ... -0.6819414  -1.13036005
#    0.64381807]]

# %%
n_groups = 3
window_size = 15
window_size = min(window_size,n_timestamps)
max_range = int(window_size/n_groups)
groups = [np.arange(i, i + max_range) for i in range(0, max_range*(n_groups-1), n_groups)]
max_range
# Out:
# 5

# %%
ssa = SingularSpectrumAnalysis(window_size=window_size, groups=groups)
X_ssa = ssa.fit_transform(X)

# %%
# Show the results for the first time series and its subseries
plt.figure(figsize=(16, 6))

ax1 = plt.subplot(121)
ax1.plot(X[0], 'o-', label='Original')
ax1.legend(loc='best', fontsize=14)

ax2 = plt.subplot(122)
for i in range(len(groups)):
    ax2.plot(X_ssa[0, i], 'o--', label='SSA {0}'.format(i + 1))
ax2.legend(loc='best', fontsize=14)

plt.suptitle('Singular Spectrum Analysis', fontsize=20)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
# The first subseries consists of the trend of the original time series.
# The second and third subseries consist of noise.

# %%
np.shape(X_ssa)
# Out:
# (100, 3, 48)
