# %%
import numpy as np
import matplotlib.pyplot as plt
from pyts.decomposition import SingularSpectrumAnalysis

# %%
from Model import *
from SQLAConnection import SQLAConnection 
from QueryGenerator import QueryGenerator
from Data import Data
import Settings

# %%
settings = Settings.Settings()
model = TimeSeriesPredictionNeuralNet(settings)
connection = SQLAConnection()
query_generator = QueryGenerator(
    settings.sensors,
    settings.start_date,
    settings.end_date
    )
data = Data(query_generator,connection)

# %%
data.load_dfs(date='2020-11-01')
df = data.dfs[0]
print(len(df))
# Out:
# 46275

# %%
n_timestamps = 100
n_samples = int(len(df)/n_timestamps)
#n_samples, n_timestamps = 15425, 3
X = data.dfs[0]['acc1_ch_y'].iloc[:n_samples*n_timestamps].to_numpy().reshape(n_samples,n_timestamps)
#print(X)

# %%
n_groups = 3
window_size = 15
window_size = min(window_size,n_timestamps)
max_range = int(window_size/n_groups)
groups = [np.arange(i, i + max_range) for i in range(0, max_range*(n_groups), max_range)]
groups
# Out:
# [array([0, 1, 2, 3, 4]), array([5, 6, 7, 8, 9]), array([10, 11, 12, 13, 14])]

# %%
ssa = SingularSpectrumAnalysis(window_size=window_size, groups=groups)
X_ssa = ssa.fit_transform(X)

# %%
# Show the results for the first time series and its subseries
plt.figure(figsize=(16, 6))

ax1 = plt.subplot(121)
ax1.plot(X[0], 'o-', label='Original')
ax1.legend(loc='best', fontsize=14)

ax2 = plt.subplot(122)
for i in range(len(groups)):
    ax2.plot(X_ssa[15, i], 'o--', label='SSA {0}'.format(i + 1))
ax2.legend(loc='best', fontsize=14)

plt.suptitle('Singular Spectrum Analysis', fontsize=20)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
# The first subseries consists of the trend of the original time series.
# The second and third subseries consist of noise.

# %%
X_ssa[:,:,:].reshape(-1,3)
#np.shape(X_ssa.reshape(-1,3,1))
#X_ssa.reshape(1,-1)
#np.shape(data.dfs[0]['acc1_ch_y'].iloc[:n_samples*n_timestamps].to_numpy())
# Out:
# array([[ 0.71430233, -0.25790152, -0.38197676],
#        [ 0.41148835,  0.17619423,  0.02180431],
#        [-0.88858099,  0.54676758,  0.53917467],
#        ...,
#        [ 0.44845416,  0.07194184,  0.44359106],
#        [-0.40552455, -0.04170266, -0.26308784],
#        [ 0.1037407 ,  0.19497538, -0.04102194]])

# %%
pd.DataFrame(X_ssa[:,:,:].reshape(-1,3))
# Out:
#               0         1         2
# 0      0.714302 -0.257902 -0.381977
# 1      0.411488  0.176194  0.021804
# 2     -0.888581  0.546768  0.539175
# 3     -0.825481  0.205597  0.234710
# 4      0.166689 -0.474728 -0.135365
# ...         ...       ...       ...
# 46195  0.123368  0.243207 -0.411234
# 46196 -0.392154 -0.197175 -0.143241
# 46197  0.448454  0.071942  0.443591
# 46198 -0.405525 -0.041703 -0.263088
# 46199  0.103741  0.194975 -0.041022
#
# [46200 rows x 3 columns]
